# %% [markdown]
# **Count**

# %%
text=input("Enter a string:  ")
count=0
for ch in text.lower():
    if ch in "aeiou":
       count +=1
print("output",count)
# Out:
# Enter a string:  Hello World
# output 3

# %%
text=input("Enter a string:  ")
count=0
for ch in text.lower():
    if ch in "aeiou":
       count=count+1
print("output",count)
# Out:
# Enter a string:  hello world
# output 3

# %% [markdown]
# **Reverse Text**

# %%
text=input("Enter String:  ")
reverse_text=text[::-1]
print("output", reverse_text)
# Out:
# Enter String:  Python
# output nohtyP

# %%
text=input("Enter String: ")
rt=text[:-3]
print("output",rt)
# Out:
# Enter String: Hello
# output He

# %% [markdown]
# **Palindrome**

# %%
text=input("Enter String: ").lower()
if text==text[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter String: Madam
# Palindrome

# %% [markdown]
# **Word Count**

# %%
text=input("Enter Sentence: ")
words=text.split()
print("words: ",len(words))
# Out:
# Enter Sentence: This is a very Intellegent boy
# words:  6
