# %% [markdown]
# Count

# %%
text=input("Enter a string:  ")
count=0
for ch in text.lower():
    if ch in "aeiou":
       count +=1
print("output",count)
# Out:
# Enter a string:  Hello World
# output 3

# %%
text=input("Enter a string:  ")
count=0
for ch in text.lower():
    if ch in "aeiou":
       count=count+1
print("output",count)
# Out:
# Enter a string:  hello world
# output 3

# %% [markdown]
# Reverse Text

# %%
text=input("Enter String")
reverse_text=text(::-1)
