# %% [markdown]
# **Count**

# %%
text=input("Enter a string:  ")
count=0
for ch in text.lower():
    if ch in "aeiou":
       count +=1
print("output",count)
# Out:
# Enter a string:  Hello
# output 2

# %%
text=input("Enter a string:  ")
count=0
for ch in text.lower():
    if ch in "aeiou":
       count=count+1
print("output",count)
# Out:
# Enter a string:  Hello World
# output 3

# %% [markdown]
# **Reverse Text**

# %%
text=input("Enter String:  ")
reverse_text=text[::-1]
print("output", reverse_text)
# Out:
# Enter String:  Python
# output nohtyP

# %%
text=input("Enter String: ")
rt=text[:-3]
print("output",rt)
# Out:
# Enter String: Python
# output Pyt

# %% [markdown]
# **Palindrome**

# %%
text=input("Enter String: ").lower()
if text==text[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter String: Madam
# Palindrome

# %% [markdown]
# **Word Count**

# %%
text=input("Enter Sentence: ")
words=text.split()
print("words: ",len(words))
# Out:
# Enter Sentence: Madam
# words:  1

# %% [markdown]
# **Replace**

# %%
text="I love AI "
r=text.replace("AI", "Artificial Intellegence")
print("Sentence: ",r)
# Out:
# Sentence:  I love Artificial Intellegence

# %% [markdown]
# **File Handling**

# %%
f=open("C:\\Users\\N TEACH\\Macine laening\\Week2 Practice Problem\\myfile.txt","x")

# %%
with open("C:\\Users\\N TEACH\\Macine laening\\Week2 Practice Problem\\myfile.txt", "a") as f:
    f.write("Name: Aftab Ahmed\nAge: 20\nDegree: Bs Computer Science")

# %%
with open("C:\\Users\\N TEACH\\Macine laening\\Week2 Practice Problem\\myfile.txt") as f:
   print( f.read())
# Out:
# Name: Aftab Ahmed
# Age: 20
# Degree: Bs Computer Science
# University: IBA

# %%
f=open("C:\\Users\\N TEACH\\Macine laening\\Week2 Practice Problem\\myfile.txt", "r")
lines=f.readlines()
print("lines",len(lines))
f.close()
# Out:
# lines 3

# %%
f=open("C:\\Users\\N TEACH\\Macine laening\\Week2 Practice Problem\\myfile.txt", "r")
data=f.read()
words=data.split()
print("Words",len(words))
f.close()
# Out:
# Words 9

# %%
f=open("C:\\Users\\N TEACH\\Macine laening\\Week2 Practice Problem\\myfile.txt", "a") 
f.write("\nUniversity: IBA")
# Out:
# 16

# %% [markdown]
# **Modules**

# %%
import math
print(math.sqrt(81))
print(math.factorial(5))
print(math.pi)
# Out:
# 9.0
# 120
# 3.141592653589793

# %%
import mymodule
import importlib

importlib.reload(mymodules)

print(mymodule.square(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 4
#       1 import mymodule
#       2 import importlib
# ----> 4 importlib.reload(mymodules)
#       6 print(mymodule.square(10))
#
# NameError: name 'mymodules' is not defined
